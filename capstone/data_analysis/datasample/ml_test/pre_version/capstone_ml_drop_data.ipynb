# %% [markdown]
# ## 클래스 합침

# %%
import pandas as pd
import numpy as np

# %%
wash_data = pd.read_csv('./wash.csv', header=None)
brush_data = pd.read_csv('./brush.csv', header=None)
walk_data = pd.read_csv('./walk.csv',header=None)
eat_data = pd.read_csv('./eat.csv', header=None)
sit_data = pd.read_csv('./sit.csv', header=None)
stand_data = pd.read_csv('./stand.csv', header=None)
dummy_data = pd.read_csv('./dummy.csv', header=None)

dummy_data[16] = 0
wash_data[16] = 1
brush_data[16] = 2
eat_data[16] = 3
walk_data[16] = 0
sit_data[16] = 0
stand_data[16] = 0

dummy_arr = dummy_data.to_numpy()
wash_arr = wash_data.to_numpy()
brush_arr = brush_data.to_numpy()
walk_arr = walk_data.to_numpy()
eat_arr = eat_data.to_numpy()
sit_arr = sit_data.to_numpy()
stand_arr = stand_data.to_numpy()

# %%
len(dummy_arr)
# Out:
# 675

# %%
import matplotlib.pyplot as plt

plt.bar(0, len(dummy_arr))
plt.bar(1, len(wash_arr))
plt.bar(2, len(brush_arr))
plt.bar(3, len(eat_arr))
plt.bar(4, len(walk_arr))
plt.bar(5, len(sit_arr))
plt.bar(6, len(stand_arr))

plt.xticks((0, 1, 2, 3, 4, 5, 6), ('Dummy', 'Wash', 'Brush', 'Eat', 'Walk', 'Sit', 'Stand'))
plt.suptitle('Num of train data')
plt.show()

# %%
tot_data = np.concatenate((dummy_arr, wash_arr[0:500], wash_arr[1000:1500], brush_arr[0:500], brush_arr[1000:1500], walk_arr, eat_arr, sit_arr, stand_arr))
train_x = tot_data[:,:-1]
train_y = tot_data[:,-1:]

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

from sklearn.svm import SVC
svm_clf = SVC(random_state=42, gamma = 0.01)

from sklearn.model_selection import cross_val_predict
y_train_pred = cross_val_predict(svm_clf, train_x, train_y.flatten(), cv=skf)

# %%
from sklearn.metrics import confusion_matrix

# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
plt.figure(figsize=(5, 5))
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# Compute confusion matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(train_y.flatten(), y_train_pred)

# Plot confusion matrix
plt.title("drop data", fontsize=15)
plt.imshow(cm,interpolation='none',cmap='Blues')
for (i, j), z in np.ndenumerate(cm):
    plt.text(j, i, z, ha='center', va='center', fontsize=13)
#plt.xlabel(['dummy', 'wash', 'brush', 'eat', 'walk', 'stand', 'sit'])
# plt.xlabel("kmeans label")
# plt.ylabel("truth label")
plt.show()

# %%
from sklearn.svm import SVC
from micromlgen import port
svm_clf = SVC(random_state=42, gamma = 0.01).fit(train_x, train_y.flatten())
print(port(svm_clf))
# Out:
# #pragma once
# /**
#  * Compute kernel between feature vector and support vector.
#  * Kernel type: rbf
#  */
# double compute_kernel(double x[16], ...) {
#     va_list w;
#     double kernel = 0.0;
#     va_start(w, 16);
#     for (uint16_t i = 0; i < 16; i++)
#             kernel += pow(x[i] -  va_arg(w, double) , 2);
#         kernel = exp(-0.01 * kernel);
#     return kernel;
# }
# /**
#  * Predict class for features vector
#  */
# int predict(double *x) {
#     double kernels[420] = { 0 };
#     double decisions[6] = { 0 };
#     int votes[4] = { 0 };
#         kernels[0] = compute_kernel(x,   10.24  , 7.89  , 4.33  , -2.43  , 2.0  , 2.24  , 3.1  , -3.58  , -5.56  , 5.45  , -0.8  , -0.8  , 0.88  , 1.66  , 0.17  , -1.23 );
#         kernels[1] = compute_kernel(x,   10.41  , 7.54  , 3.99  , -2.44  , 2.31  , 3.46  , 4.15  , -1.29  , -1.74  , 7.23  , -0.16  , -0.12  , 0.76  , -1.32  , 0.46  , 1.0 );
#         kernels[2] = compute_kernel(x,   10.06  , 9.37  , -0.52  , 3.31  , 1.07  , 0.69  , 1.34  , -0.08  , -0.04  , 0.02  , -0.1  , -0.05  , 0.01  , -0.77  , 0.24  , -0.28 );
#         kernels[3] = compute_kernel(x,   10.14  , 8.33  , 1.83  , 4.32  , 1.13  , 2.92  , 1.8  , -1.85  , 2.74  , -0.34  , -0.56  , 0.52  , -0.17  , -0.6  , 0.35  , -0.6 );
#         kernels[4] = compute_kernel(x,   10.06  , 6.24  , 2.31  , 7.04  , 1.53  , 1.14  , 2.05  , 1.56  , -2.11  , -3.03  , 0.89  , -0.9  , -0.97  , -0.18  , 0.66  , 0.42 );
#         kernels[5] = compute_kernel(x,   10.01  , 4.15  , 4.65  , 7.17  , 1.38  , 2.75  , 1.76  , -2.16  , -1.97  , 1.78  , -0.57  , -0.41  , 0.73  , -0.1  , 0.1  , 0.76 );
#         kernels[6] = compute_kernel(x,   10.25  , 5.66  , 1.81  , 7.91  , 1.65  , 2.35  , 1.93  , 0.2  , 2.07  , 1.12  , 0.05  , 0.46  , 0.35  , 0.05  , 0.02  , 1.01 );
#         kernels[7] = compute_kernel(x,   10.2  , 8.34  , 2.97  , 5.02  , 0.26  , 0.53  , 0.37  , -0.12  , -0.01  , -0.02  , -0.85  , -0.04  , -0.18  , 0.03  , 0.09  , 0.1 );
#         kernels[8] = compute_kernel(x,   10.04  , 8.5  , 1.15  , 4.68  , 0.89  , 2.01  , 1.0  , -0.4  , 1.19  , -0.36  , -0.22  , 0.59  , -0.4  , -0.91  , -0.03  , 0.06 );
#         kernels[9] = compute_kernel(x,   10.44  , 8.61  , -0.5  , 5.42  , 1.28  , 1.28  , 1.92  , 0.47  , 0.06  , -0.56  , 0.29  , 0.03  , -0.23  , -1.13  , 0.01  , -0.38 );
#         kernels[10] = compute_kernel(x,   10.31  , 8.3  , -0.45  , 5.82  , 1.42  , 1.2  , 1.73  , 0.19  , -0.42  , 0.73  , 0.11  , -0.2  , 0.29  , -0.31  , 0.01  , -0.36 );
#         kernels[11] = compute_kernel(x,   10.09  , 9.53  , 1.85  , 2.71  , 0.65  , 0.32  , 0.55  , 0.04  , -0.01  , 0.27  , 0.18  , -0.06  , 0.76  , -0.0  , -0.06  , -0.04 );
#         kernels[12] = compute_kernel(x,   9.89  , 6.91  , 6.09  , 2.19  , 1.37  , 2.42  , 0.92  , -3.04  , -1.86  , 1.0  , -0.92  , -0.83  , 0.8  , 0.19  , -0.35  , -0.95 );
#         kernels[13] = compute_kernel(x,   10.05  , 5.37  , 8.21  , 1.58  , 1.11  , 1.1  , 0.65  , -0.79  , -0.47  , 0.48  , -0.65  , -0.65  , 0.67  , -0.08  , -0.07  , -0.13 );
#         kernels[14] = compute_kernel(x,   9.87  , 4.61  , 8.32  , 2.01  , 1.22  , 1.1  , 0.76  , -0.81  , 0.17  , -0.54  , -0.6  , 0.21  , -0.58  , -0.0  , 0.06  , -0.26 );
#         kernels[15] = compute_kernel(x,   9.73  , 3.56  , 8.67  , 1.69  , 1.34  , 1.24  , 1.6  , 0.13  , 1.03  , -1.49  , 0.08  , 0.52  , -0.7  , 0.11  , -0.16  , 0.05 );
#         kernels[16] = compute_kernel(x,   9.86  , 4.05  , 8.85  , 0.21  , 1.3  , 1.47  , 0.7  , -0.18  , 0.23  , 0.2  , -0.09  , 0.23  , 0.22  , 0.0  , -0.17  , -0.0 );
#         kernels[17] = compute_kernel(x,   10.01  , 6.43  , 7.36  , 1.55  , 1.19  , 1.09  , 0.35  , -0.84  , 0.16  , 0.04  , -0.65  , 0.41  , 0.1  , 0.01  , -0.02  , 0.02 );
#         kernels[18] = compute_kernel(x,   9.93  , 6.56  , 7.09  , 1.69  , 1.2  , 1.47  , 0.73  , -0.28  , 0.1  , 0.28  , -0.16  , 0.1  , 0.32  , -0.18  , -0.06  , 0.3 );
#         kernels[19] = compute_kernel(x,   10.41  , 6.6  , 4.88  , 4.8  , 1.79  , 2.32  , 3.42  , 3.31  , -5.81  , -3.34  , 0.8  , -0.73  , -0.54  , -0.48  , 0.83  , 0.24 );
#         kernels[20] = compute_kernel(x,   9.78  , 1.22  , 2.46  , 8.96  , 2.56  , 1.05  , 0.82  , 2.29  , -0.5  , -0.77  , 0.85  , -0.59  , -0.37  , 0.29  , -0.96  , 0.25 );
#         kernels[21] = compute_kernel(x,   10.05  , 8.4  , 2.5  , 4.18  , 0.54  , 2.15  , 1.64  , -0.66  , 2.48  , -0.01  , -0.56  , 0.7  , -0.02  , -0.29  , -0.35  , 0.49 );
#         kernels[22] = compute_kernel(x,   10.18  , 9.09  , 4.26  , 1.23  , 0.47  , 0.97  , 0.74  , -0.1  , -0.02  , 0.03  , -0.21  , -0.03  , 0.09  , 0.23  , 0.01  , -0.16 );
#         kernels[23] = compute_kernel(x,   10.35  , 8.77  , 5.02  , 1.1  , 0.59  , 1.26  , 1.5  , -0.27  , -0.25  , -0.01  , -0.37  , -0.13  , -0.01  , 0.39  , 0.15  , -0.02 );
#         kernels[24] = compute_kernel(x,   10.26  , 10.24  , -0.66  , 0.2  , 0.17  , 0.26  , 0.06  , -0.01  , -0.01  , 0.0  , -0.23  , -0.64  , 0.31  , -0.0  , -0.02  , -0.04 );
#         kernels[25] = compute_kernel(x,   10.31  , 10.14  , -1.67  , 0.6  , 0.3  , 0.26  , 0.52  , 0.01  , 0.02  , 0.12  , 0.19  , 0.15  , 0.77  , -0.27  , -0.24  , -0.08 );
#         kernels[26] = compute_kernel(x,   10.57  , 9.31  , 0.92  , 4.12  , 1.87  , 1.39  , 2.05  , 0.31  , 1.55  , -2.38  , 0.12  , 0.55  , -0.62  , 0.32  , -0.79  , 0.36 );
#         kernels[27] = compute_kernel(x,   10.24  , 7.91  , 4.11  , 0.06  , 1.28  , 4.71  , 1.55  , -5.81  , -1.84  , 0.76  , -0.97  , -0.25  , 0.38  , 0.55  , 0.15  , 0.75 );
#         kernels[28] = compute_kernel(x,   10.53  , 8.59  , 2.96  , -0.33  , 1.99  , 4.79  , 1.79  , -8.25  , -1.61  , 0.81  , -0.86  , -0.19  , 0.23  , 0.57  , 0.14  , 0.68 );
#         kernels[29] = compute_kernel(x,   10.32  , 7.14  , 6.14  , -1.09  , 1.04  , 3.59  , 1.98  , -2.95  , 5.4  , -1.57  , -0.79  , 0.76  , -0.77  , 0.56  , 0.1  , 0.64 );
#         kernels[30] = compute_kernel(x,   10.26  , 7.29  , 6.18  , -2.21  , 0.71  , 2.79  , 1.26  , -0.81  , 2.77  , -0.65  , -0.41  , 0.79  , -0.73  , 0.48  , 0.03  , 0.64 );
#         kernels[31] = compute_kernel(x,   10.33  , 8.54  , 3.17  , -2.53  , 1.52  , 3.67  , 1.7  , -2.89  , -2.15  , 1.34  , -0.52  , -0.34  , 0.52  , -0.56  , -0.18  , -0.64 );
#         kernels[32] = compute_kernel(x,   10.09  , 7.55  , 4.17  , -2.25  , 1.78  , 3.91  , 2.23  , -5.22  , -3.73  , 2.65  , -0.75  , -0.43  , 0.67  , 0.45  , 0.41  , 0.63 );
#         kernels[33] = compute_kernel(x,   10.36  , 7.51  , 5.62  , -3.75  , 0.83  , 2.12  , 1.31  , 0.47  , 1.46  , -0.54  , 0.27  , 0.53  , -0.5  , 0.5  , 0.08  , 0.41 );
#         kernels[34] = compute_kernel(x,   10.24  , 7.18  , 4.56  , -2.83  , 1.58  , 3.91  , 2.68  , -5.33  , -3.97  , 2.37  , -0.86  , -0.38  , 0.56  , 0.55  , 0.43  , 0.65 );
#         kernels[35] = compute_kernel(x,   10.41  , 8.46  , 1.6  , -1.91  , 2.12  , 4.24  , 3.05  , -6.97  , -8.84  , 6.3  , -0.78  , -0.68  , 0.98  , -0.51  , -0.61  , -0.73 );
#         kernels[36] = compute_kernel(x,   10.37  , 6.93  , 5.43  , -4.13  , 0.37  , 3.51  , 1.49  , -0.58  , 4.46  , -0.33  , -0.44  , 0.85  , -0.6  , 0.49  , 0.01  , 0.42 );
#         kernels[37] = compute_kernel(x,   10.35  , 7.34  , 4.8  , -4.38  , 0.54  , 3.08  , 1.6  , -0.04  , -1.07  , -0.25  , -0.02  , -0.22  , -0.29  , 0.61  , 0.28  , 0.45 );
#         kernels[38] = compute_kernel(x,   10.37  , 7.45  , 5.97  , -3.79  , 0.5  , 0.76  , 1.28  , 0.12  , 0.19  , 0.34  , 0.32  , 0.19  , 0.53  , -0.31  , 0.11  , -0.29 );
#         kernels[39] = compute_kernel(x,   10.52  , 8.47  , 1.93  , -1.18  , 1.75  , 4.53  , 3.31  , -6.57  , -10.04  , 4.76  , -0.83  , -0.67  , 0.82  , -0.55  , -0.4  , -0.68 );
#         kernels[40] = compute_kernel(x,   10.34  , 7.79  , 4.59  , -4.16  , 0.6  , 2.69  , 0.77  , -0.79  , 1.77  , -0.37  , -0.49  , 0.85  , -0.79  , 0.38  , 0.08  , 0.54 );
#         kernels[41] = compute_kernel(x,   10.3  , 7.92  , 3.55  , -3.3  , 1.04  , 3.73  , 2.33  , -2.78  , -1.99  , 1.19  , -0.72  , -0.23  , 0.49  , 0.51  , 0.31  , 0.53 );
#         kernels[42] = compute_kernel(x,   10.27  , 7.09  , 6.41  , -3.72  , 0.38  , 0.54  , 0.16  , -0.03  , -0.05  , 0.03  , -0.16  , -0.57  , 0.4  , 0.02  , -0.01  , 0.46 );
#         kernels[43] = compute_kernel(x,   10.37  , 8.3  , 3.46  , -3.15  , 1.42  , 2.99  , 2.56  , -2.58  , -1.66  , 2.05  , -0.61  , -0.22  , 0.57  , 0.42  , 0.39  , 0.51 );
#         kernels[44] = compute_kernel(x,   10.37  , 7.07  , 6.47  , -3.9  , 0.18  , 1.08  , 0.15  , 0.13  , -0.1  , -0.01  , 0.64  , -0.66  , -0.29  , 0.03  , -0.04  , 0.18 );
#         kernels[45] = compute_kernel(x,   10.38  , 7.81  , 3.83  , -3.42  , 1.72  , 3.48  , 2.84  , -1.89  , -3.9  , 3.02  , -0.32  , -0.39  , 0.62  , 0.56  , 0.46  , 0.45 );
#         kernels[46] = compute_kernel(x,   10.61  , 8.73  , 1.47  , -2.13  , 2.28  , 3.54  , 3.77  , -5.19  , -10.44  , 7.41  , -0.64  , -0.78  , 0.86  , -0.67  , -0.55  , -0.41 );
#         kernels[47] = compute_kernel(x,   10.36  , 6.89  , 6.57  , -4.05  , 0.38  , 0.72  , 0.41  , -0.1  , 0.01  , -0.14  , -0.38  , 0.05  , -0.9  , 0.07  , -0.03  , 0.32 );
#         kernels[48] = compute_kernel(x,   10.23  , 7.6  , 4.67  , -3.04  , 1.27  , 3.09  , 2.38  , -2.92  , -2.32  , 1.54  , -0.74  , -0.32  , 0.51  , 0.75  , 0.44  , 0.41 );
#         kernels[49] = compute_kernel(x,   10.41  , 7.84  , 3.8  , -3.55  , 1.8  , 2.8  , 3.3  , -1.82  , -6.07  , 4.99  , -0.36  , -0.66  , 0.84  , -0.72  , -0.58  , -0.21 );
#         kernels[50] = compute_kernel(x,   10.28  , 10.26  , -0.55  , 0.06  , 0.28  , 0.27  , 0.14  , -0.03  , -0.01  , 0.02  , -0.35  , -0.33  , 0.4  , 0.01  , 0.01  , -0.05 );
#         kernels[51] = compute_kernel(x,   10.27  , 8.23  , 3.55  , -3.06  , 1.25  , 3.02  , 2.46  , -1.36  , -2.57  , 2.67  , -0.36  , -0.34  , 0.87  , -0.68  , -0.46  , -0.46 );
#         kernels[52] = compute_kernel(x,   10.09  , 7.19  , 6.4  , -2.93  , 0.54  , 0.78  , 0.23  , -0.04  , -0.01  , -0.02  , -0.1  , -0.06  , -0.17  , 0.01  , -0.01  , -0.03 );
#         kernels[53] = compute_kernel(x,   10.25  , 6.56  , 6.61  , -4.14  , 0.65  , 0.59  , 0.69  , -0.33  , -0.29  , 0.4  , -0.85  , -0.71  , 0.89  , 0.19  , -0.01  , -0.16 );
#         kernels[54] = compute_kernel(x,   10.62  , 6.62  , 6.38  , -5.2  , 0.76  , 0.9  , 1.29  , -0.11  , -0.14  , -0.93  , -0.16  , -0.12  , -0.94  , 0.17  , -0.09  , 0.22 );
#         kernels[55] = compute_kernel(x,   11.22  , 6.01  , 2.04  , -5.6  , 1.95  , 6.36  , 3.84  , 8.64  , -5.03  , -1.7  , 0.69  , -0.21  , -0.23  , 1.15  , -0.1  , 0.74 );
#         kernels[56] = compute_kernel(x,   11.77  , 6.55  , -5.54  , -3.53  , 2.33  , 5.79  , 4.29  , 3.39  , -11.33  , 1.81  , 0.25  , -0.46  , 0.18  , 1.12  , 0.65  , 0.68 );
#         kernels[57] = compute_kernel(x,   10.6  , 6.72  , 1.68  , -3.3  , 2.61  , 5.95  , 4.08  , 9.48  , -8.46  , -4.83  , 0.61  , -0.35  , -0.45  , -0.77  , 0.03  , -0.83 );
#         kernels[58] = compute_kernel(x,   10.42  , 8.0  , 5.19  , -3.81  , 0.5  , 1.25  , 1.27  , 0.01  , 0.54  , 0.35  , 0.02  , 0.34  , 0.55  , -0.34  , 0.08  , -0.39 );
#         kernels[59] = compute_kernel(x,   10.32  , 8.94  , 1.08  , -4.58  , 0.66  , 1.69  , 1.18  , -0.07  , -0.14  , 0.57  , -0.06  , -0.07  , 0.72  , -0.33  , -0.17  , 0.27 );
#         kernels[60] = compute_kernel(x,   10.55  , 9.22  , 1.58  , -3.51  , 1.25  , 2.79  , 2.17  , 2.52  , 3.2  , 1.74  , 0.72  , 0.53  , 0.64  , -0.03  , 0.37  , -0.18 );
#         kernels[61] = compute_kernel(x,   10.24  , 8.96  , 3.01  , -3.05  , 1.01  , 1.77  , 1.58  , -0.12  , 0.08  , 1.39  , -0.06  , 0.03  , 0.87  , -0.42  , -0.28  , -0.23 );
#         kernels[62] = compute_kernel(x,   10.38  , 8.08  , 5.57  , -3.3  , 0.3  , 0.7  , 0.4  , 0.03  , 0.21  , 0.01  , 0.16  , 0.73  , 0.07  , -0.01  , -0.06  , 0.18 );
#         kernels[63] = compute_kernel(x,   10.24  , 8.69  , 3.46  , -3.25  , 1.16  , 2.19  , 1.37  , 0.07  , 0.39  , 1.21  , 0.03  , 0.13  , 0.77  , -0.45  , -0.27  , -0.38 );
#         kernels[64] = compute_kernel(x,   10.09  , 7.87  , 5.43  , -2.65  , 0.64  , 1.46  , 1.13  , 0.14  , 1.02  , 0.35  , 0.15  , 0.62  , 0.49  , -0.19  , -0.12  , -0.09 );
#         kernels[65] = compute_kernel(x,   10.08  , 7.19  , 6.24  , -2.57  , 0.58  , 1.83  , 1.1  , -0.31  , 1.8  , -0.17  , -0.29  , 0.9  , -0.27  , -0.16  , -0.09  , -0.04 );
#         kernels[66] = compute_kernel(x,   10.11  , 6.59  , 6.95  , -2.9  , 0.53  , 0.71  , 1.25  , 0.28  , 0.58  , 0.44  , 0.74  , 0.65  , 0.66  , 0.55  , 0.39  , -0.33 );
#         kernels[67] = compute_kernel(x,   10.14  , 6.32  , 6.72  , -4.15  , 0.53  , 0.62  , 0.45  , 0.22  , 0.16  , 0.13  , 0.66  , 0.57  , 0.53  , 0.63  , 0.41  , -0.36 );
#         kernels[68] = compute_kernel(x,   10.15  , 5.36  , 6.61  , -5.52  , 0.26  , 0.27  , 0.4  , 0.02  , 0.04  , 0.03  , 0.29  , 0.33  , 0.27  , -0.16  , -0.32  , 0.22 );
#         kernels[69] = compute_kernel(x,   10.17  , 6.43  , 6.88  , -3.26  , 0.93  , 1.44  , 1.23  , -0.98  , 0.81  , -0.77  , -0.73  , 0.46  , -0.67  , 0.13  , 0.11  , 0.33 );
#         kernels[70] = compute_kernel(x,   10.17  , 7.21  , 6.13  , -3.03  , 1.07  , 1.65  , 1.19  , -1.25  , 0.42  , -0.43  , -0.71  , 0.21  , -0.34  , 0.17  , 0.11  , -0.13 );
#         kernels[71] = compute_kernel(x,   10.15  , 7.07  , 7.07  , -1.48  , 0.32  , 0.57  , 0.84  , 0.07  , 0.01  , 0.0  , 0.4  , 0.01  , 0.01  , 0.19  , 0.03  , -0.04 );
#         kernels[72] = compute_kernel(x,   10.11  , 7.84  , 4.53  , -2.44  , 1.5  , 3.19  , 1.4  , -4.73  , -0.81  , 0.6  , -0.99  , -0.18  , 0.29  , -0.71  , -0.4  , -0.75 );
#         kernels[73] = compute_kernel(x,   10.22  , 9.57  , 2.01  , -2.23  , 1.05  , 1.31  , 1.31  , -0.36  , -0.88  , 1.0  , -0.26  , -0.51  , 0.73  , -0.59  , -0.24  , -0.24 );
#         kernels[74] = compute_kernel(x,   10.28  , 7.97  , 6.16  , -1.96  , 0.36  , 0.62  , 0.07  , -0.09  , -0.01  , -0.01  , -0.4  , -0.12  , -0.23  , 0.05  , -0.02  , 0.36 );
#         kernels[75] = compute_kernel(x,   10.37  , 8.28  , 5.3  , -2.58  , 0.79  , 1.68  , 1.18  , -0.25  , 1.05  , -0.11  , -0.19  , 0.53  , -0.11  , -0.47  , -0.04  , -0.54 );
#         kernels[76] = compute_kernel(x,   10.26  , 7.95  , 6.18  , -1.99  , 0.27  , 0.43  , 0.09  , 0.09  , 0.02  , 0.01  , 0.77  , 0.48  , 0.57  , 0.01  , -0.04  , 0.38 );
#         kernels[77] = compute_kernel(x,   10.32  , 7.52  , 6.47  , -2.73  , 0.53  , 0.61  , 0.47  , -0.19  , 0.19  , -0.17  , -0.59  , 0.68  , -0.69  , 0.1  , -0.06  , 0.39 );
#         kernels[78] = compute_kernel(x,   10.11  , 8.62  , 4.68  , -1.12  , 1.49  , 1.66  , 0.7  , -2.21  , -0.25  , 0.2  , -0.89  , -0.22  , 0.19  , 0.33  , 0.42  , 0.53 );
#         kernels[79] = compute_kernel(x,   10.16  , 7.96  , 5.51  , -2.96  , 0.44  , 0.54  , 0.51  , -0.04  , -0.0  , 0.18  , -0.17  , -0.01  , 0.8  , -0.18  , -0.17  , -0.05 );
#         kernels[80] = compute_kernel(x,   10.08  , 5.76  , 6.73  , -4.71  , 0.53  , 0.82  , 0.63  , 0.11  , 0.37  , 0.05  , 0.25  , 0.73  , 0.14  , 0.64  , 0.4  , -0.31 );
#         kernels[81] = compute_kernel(x,   10.12  , 4.87  , 6.29  , -6.22  , 0.45  , 0.54  , 0.39  , 0.06  , 0.01  , 0.11  , 0.24  , 0.06  , 0.63  , -0.11  , -0.42  , 0.2 );
#         kernels[82] = compute_kernel(x,   10.25  , 6.56  , 6.2  , -4.24  , 1.25  , 1.91  , 0.76  , -2.15  , 1.17  , -0.75  , -0.9  , 0.81  , -0.79  , 0.2  , 0.04  , 0.62 );
#         kernels[83] = compute_kernel(x,   10.32  , 7.88  , 3.75  , -4.35  , 0.87  , 3.26  , 0.53  , -2.25  , 1.69  , -0.38  , -0.8  , 0.97  , -0.83  , 0.6  , -0.03  , 0.72 );
#         kernels[84] = compute_kernel(x,   10.23  , 8.77  , -1.23  , -3.43  , 0.46  , 3.42  , 1.68  , -0.73  , -2.83  , 0.02  , -0.46  , -0.49  , 0.02  , 0.97  , 0.05  , 0.77 );
#         kernels[85] = compute_kernel(x,   10.35  , 0.61  , 1.77  , 10.12  , 0.93  , 0.68  , 1.53  , -0.07  , 0.41  , 0.2  , -0.11  , 0.4  , 0.14  , -0.07  , -0.06  , -0.09 );
#         kernels[86] = compute_kernel(x,   10.56  , 0.8  , 0.15  , 10.41  , 1.29  , 0.93  , 2.09  , 0.06  , -0.8  , 0.75  , 0.05  , -0.42  , 0.28  , -0.1  , -0.06  , 0.3 );
#         kernels[87] = compute_kernel(x,   11.26  , 1.06  , 1.42  , 10.82  , 1.7  , 2.08  , 1.7  , 1.95  , 2.39  , 0.74  , 0.55  , 0.68  , 0.26  , 0.05  , -0.07  , 0.22 );
#         kernels[88] = compute_kernel(x,   10.07  , 0.81  , 1.34  , 9.45  , 1.38  , 2.86  , 2.37  , -2.06  , -4.29  , 1.88  , -0.52  , -0.63  , 0.57  , -0.23  , 0.24  , 0.36 );
#         kernels[89] = compute_kernel(x,   10.98  , 0.69  , 1.64  , 10.44  , 1.4  , 2.56  , 2.31  , -0.08  , 1.55  , -0.31  , -0.02  , 0.26  , -0.1  , 0.05  , 0.42  , 0.62 );
#         kernels[90] = compute_kernel(x,   9.97  , 1.14  , 1.14  , 9.65  , 0.94  , 1.86  , 1.71  , -0.17  , 0.99  , 0.25  , -0.1  , 0.31  , 0.16  , -0.04  , 0.32  , -0.82 );
#         kernels[91] = compute_kernel(x,   10.01  , 0.56  , 1.54  , 9.65  , 1.08  , 1.97  , 1.83  , -0.26  , 1.05  , -0.12  , -0.12  , 0.29  , -0.06  , 0.58  , -0.06  , -0.33 );
#         kernels[92] = compute_kernel(x,   9.85  , 2.22  , 4.31  , 7.44  , 2.31  , 3.15  , 2.12  , 1.39  , -5.23  , 0.26  , 0.19  , -0.78  , 0.05  , 1.22  , 0.04  , -0.26 );
#         kernels[93] = compute_kernel(x,   11.13  , 6.3  , -4.2  , -6.22  , 3.12  , 1.91  , 4.28  , 4.58  , 6.97  , 11.46  , 0.77  , 0.85  , 0.86  , 0.29  , 0.81  , -0.5 );
#         kernels[94] = compute_kernel(x,   10.08  , 9.16  , -3.12  , -2.53  , 1.05  , 0.81  , 0.97  , 0.22  , 0.25  , -0.5  , 0.27  , 0.32  , -0.49  , -0.05  , 0.28  , -0.2 );
#         kernels[95] = compute_kernel(x,   9.97  , 0.05  , -2.06  , -9.71  , 0.61  , 0.75  , 0.64  , -0.21  , 0.35  , -0.15  , -0.46  , 0.72  , -0.39  , 0.03  , -0.08  , -0.22 );
#         kernels[96] = compute_kernel(x,   10.82  , 7.27  , -3.32  , -5.18  , 2.99  , 1.54  , 4.47  , 0.18  , 1.5  , 11.44  , 0.04  , 0.22  , 0.86  , 0.19  , 1.11  , -0.21 );
#         kernels[97] = compute_kernel(x,   10.13  , 9.1  , -3.49  , -2.39  , 1.1  , 1.23  , 0.65  , -0.41  , -0.02  , 0.41  , -0.3  , -0.03  , 0.58  , -0.15  , 0.33  , 0.16 );
#         kernels[98] = compute_kernel(x,   10.3  , 1.81  , -3.17  , -9.25  , 2.33  , 1.46  , 1.03  , -2.96  , -0.34  , 0.66  , -0.87  , -0.23  , 0.28  , 0.43  , 0.71  , -0.5 );
#         kernels[99] = compute_kernel(x,   10.83  , 6.1  , -4.21  , -6.65  , 2.85  , 1.5  , 2.94  , -1.21  , -0.79  , 7.49  , -0.28  , -0.18  , 0.89  , 0.42  , 1.0  , -0.52 );
#         kernels[100] = compute_kernel(x,   10.29  , 1.38  , -1.83  , -10.03  , 0.16  , 0.1  , 0.13  , 0.01  , 0.0  , -0.01  , 0.45  , 0.07  , -0.37  , -0.04  , 0.01  , 0.06 );
#         kernels[101] = compute_kernel(x,   11.25  , 0.97  , -3.33  , -10.63  , 0.86  , 1.64  , 1.94  , -1.32  , 2.97  , -1.43  , -0.93  , 0.93  , -0.85  , 0.38  , 0.56  , -0.43 );
#         kernels[102] = compute_kernel(x,   11.41  , 5.09  , -4.31  , -6.78  , 3.71  , 1.24  , 5.43  , 1.34  , 3.33  , 18.76  , 0.29  , 0.49  , 0.93  , 0.39  , 1.06  , -0.35 );
#         kernels[103] = compute_kernel(x,   10.66  , 3.82  , -3.89  , -7.97  , 3.31  , 1.45  , 3.22  , -3.46  , -1.6  , 8.41  , -0.72  , -0.34  , 0.79  , 0.41  , 0.9  , -0.58 );
#         kernels[104] = compute_kernel(x,   11.11  , 3.57  , -3.36  , -9.01  , 2.77  , 1.29  , 3.54  , -0.61  , 0.95  , 7.59  , -0.17  , 0.21  , 0.77  , 0.44  , 0.94  , -0.6 );
#         kernels[105] = compute_kernel(x,   10.15  , 8.42  , -5.07  , -2.02  , 1.66  , 1.19  , 1.13  , -1.06  , -0.0  , 0.51  , -0.54  , -0.0  , 0.27  , -0.03  , 0.1  , -0.03 );
#         kernels[106] = compute_kernel(x,   10.45  , 6.96  , -3.36  , -5.78  , 2.65  , 1.38  , 2.73  , -1.85  , -2.01  , 6.3  , -0.51  , -0.53  , 0.87  , -0.69  , -1.25  , 0.15 );
#         kernels[107] = compute_kernel(x,   10.69  , 2.16  , -1.85  , -9.45  , 3.4  , 1.59  , 2.44  , -4.43  , -2.71  , 5.61  , -0.82  , -0.7  , 0.67  , -0.48  , -0.84  , 0.26 );
#         kernels[108] = compute_kernel(x,   10.14  , 2.2  , -3.96  , -8.52  , 1.71  , 2.5  , 1.82  , -4.12  , -1.59  , 1.06  , -0.97  , -0.35  , 0.34  , -0.52  , -0.11  , 0.58 );
#         kernels[109] = compute_kernel(x,   10.26  , 2.5  , -4.0  , -8.5  , 1.91  , 2.53  , 1.69  , -3.99  , -1.51  , 1.67  , -0.83  , -0.35  , 0.52  , -0.48  , -0.29  , 0.64 );
#         kernels[110] = compute_kernel(x,   10.34  , 1.65  , -3.65  , -8.98  , 1.23  , 2.88  , 1.81  , -3.15  , -1.5  , 1.09  , -0.89  , -0.29  , 0.49  , -0.68  , -0.18  , 0.59 );
#         kernels[111] = compute_kernel(x,   10.52  , 7.12  , -4.81  , -4.72  , 2.44  , 2.24  , 1.98  , 4.57  , 3.46  , 4.56  , 0.84  , 0.78  , 0.94  , 0.05  , -0.77  , 0.41 );
#         kernels[112] = compute_kernel(x,   10.63  , 3.08  , -4.66  , -8.12  , 2.52  , 2.58  , 2.44  , -5.23  , -2.98  , 3.86  , -0.81  , -0.47  , 0.63  , -0.46  , -0.75  , 0.86 );
#         kernels[113] = compute_kernel(x,   10.1  , 1.34  , -2.0  , -9.8  , 0.37  , 0.29  , 0.37  , -0.0  , 0.01  , -0.12  , -0.02  , 0.07  , -0.88  , -0.07  , 0.1  , -0.02 );
#         kernels[114] = compute_kernel(x,   10.29  , 1.27  , -2.01  , -10.01  , 0.22  , 0.32  , 0.17  , -0.02  , 0.04  , -0.01  , -0.31  , 0.75  , -0.22  , 0.01  , -0.01  , -0.08 );
#         kernels[115] = compute_kernel(x,   10.37  , 2.61  , -3.49  , -8.71  , 2.43  , 2.6  , 2.77  , -5.39  , -0.02  , 1.67  , -0.85  , -0.0  , 0.25  , -0.37  , -0.36  , 0.48 );
#         kernels[116] = compute_kernel(x,   10.31  , 8.72  , -4.3  , -3.25  , 0.45  , 0.64  , 0.94  , -0.03  , 0.28  , 0.29  , -0.11  , 0.47  , 0.69  , 0.07  , -0.46  , 0.06 );
#         kernels[117] = compute_kernel(x,   10.38  , 3.35  , -3.11  , -8.67  , 2.47  , 1.57  , 2.99  , -2.34  , 0.72  , 4.09  , -0.6  , 0.15  , 0.55  , -0.2  , -0.6  , 0.23 );
#         kernels[118] = compute_kernel(x,   11.12  , 4.97  , -4.33  , -7.47  , 2.85  , 1.82  , 4.08  , -4.12  , -3.74  , 9.6  , -0.79  , -0.5  , 0.83  , -0.19  , -1.07  , -0.22 );
#         kernels[119] = compute_kernel(x,   10.71  , 3.79  , -4.06  , -8.19  , 2.94  , 2.04  , 2.29  , -4.64  , -1.44  , 5.14  , -0.77  , -0.31  , 0.76  , -0.37  , -0.67  , 0.19 );
#         kernels[120] = compute_kernel(x,   10.29  , 1.27  , -2.14  , -9.98  , 0.24  , 0.39  , 0.24  , -0.04  , 0.01  , -0.03  , -0.42  , 0.14  , -0.55  , 0.03  , -0.01  , -0.0 );
#         kernels[121] = compute_kernel(x,   9.54  , 1.03  , -1.49  , -9.28  , 0.6  , 1.19  , 1.01  , -0.5  , 0.51  , -0.27  , -0.7  , 0.42  , -0.45  , -0.11  , 0.23  , 0.18 );
#         kernels[122] = compute_kernel(x,   10.37  , 1.57  , -2.05  , -10.03  , 0.35  , 0.51  , 0.28  , -0.11  , 0.03  , -0.07  , -0.62  , 0.24  , -0.77  , -0.15  , -0.01  , 0.26 );
#         kernels[123] = compute_kernel(x,   10.08  , 6.05  , 2.05  , 7.56  , 1.11  , 0.81  , 1.75  , -0.31  , -1.06  , 0.14  , -0.34  , -0.75  , 0.07  , 0.18  , -0.21  , -0.37 );
#         kernels[124] = compute_kernel(x,   11.53  , 6.69  , 4.21  , 6.16  , 0.95  , 4.63  , 5.2  , 1.4  , 22.27  , 1.16  , 0.32  , 0.92  , 0.23  , 0.13  , -0.12  , 0.1 );
#         kernels[125] = compute_kernel(x,   10.3  , -0.56  , 5.77  , 4.5  , 6.01  , 4.51  , 3.93  , -9.78  , 13.54  , -3.17  , -0.36  , 0.77  , -0.13  , 0.06  , 0.09  , -1.35 );
#         kernels[126] = compute_kernel(x,   10.78  , -7.04  , 5.03  , 4.16  , 5.6  , 1.71  , 3.59  , -0.89  , 2.66  , -17.12  , -0.09  , 0.43  , -0.85  , -0.13  , -0.19  , -0.09 );
#         kernels[127] = compute_kernel(x,   10.91  , -6.54  , 4.81  , 4.16  , 6.09  , 2.16  , 4.52  , 4.35  , -3.57  , -25.18  , 0.33  , -0.37  , -0.91  , -0.06  , 0.01  , 0.18 );
#         kernels[128] = compute_kernel(x,   10.37  , -7.99  , 2.87  , 3.56  , 4.59  , 2.35  , 3.48  , 7.84  , -5.86  , -14.3  , 0.73  , -0.72  , -0.9  , -0.19  , 0.05  , 0.39 );
#         kernels[129] = compute_kernel(x,   10.61  , -7.63  , 3.62  , 3.57  , 4.59  , 3.22  , 2.58  , 11.89  , -4.88  , -10.69  , 0.8  , -0.59  , -0.9  , 0.0  , -0.08  , -0.14 );
#         kernels[130] = compute_kernel(x,   9.83  , -5.25  , 4.11  , 4.25  , 4.94  , 2.56  , 1.97  , 6.74  , 2.35  , 8.36  , 0.53  , 0.46  , 0.86  , -0.39  , -0.26  , 1.44 );
#         kernels[131] = compute_kernel(x,   10.24  , -1.19  , 6.36  , 3.37  , 7.04  , 1.68  , 2.88  , 1.44  , -2.14  , -10.74  , 0.12  , -0.44  , -0.53  , 0.0  , 0.06  , 1.37 );
#         kernels[132] = compute_kernel(x,   10.07  , 6.3  , 3.32  , 6.81  , 0.89  , 1.67  , 1.07  , -0.8  , -0.94  , -0.0  , -0.54  , -0.52  , -0.0  , -0.04  , 0.37  , 0.48 );
#         kernels[133] = compute_kernel(x,   9.97  , -0.13  , 5.34  , 4.53  , 6.54  , 1.93  , 2.24  , -10.03  , -3.78  , 13.62  , -0.79  , -0.87  , 0.93  , 0.12  , -0.23  , 1.05 );
#         kernels[134] = compute_kernel(x,   9.6  , -3.58  , 6.19  , 2.25  , 5.49  , 2.16  , 1.47  , 8.84  , 2.47  , 7.02  , 0.74  , 0.78  , 0.87  , -0.11  , -0.18  , 1.53 );
#         kernels[135] = compute_kernel(x,   9.68  , -5.15  , 6.27  , 1.5  , 4.35  , 2.39  , 1.18  , 10.06  , 2.73  , 4.78  , 0.97  , 0.97  , 0.93  , -0.18  , -0.16  , 1.18 );
#         kernels[136] = compute_kernel(x,   9.87  , 4.18  , 8.29  , 2.53  , 1.77  , 1.55  , 0.39  , -2.19  , -0.06  , 0.25  , -0.8  , -0.1  , 0.36  , 0.08  , -0.06  , -0.14 );
#         kernels[137] = compute_kernel(x,   9.95  , 5.28  , 7.97  , 1.55  , 0.94  , 1.89  , 1.75  , -0.68  , 0.33  , 0.69  , -0.38  , 0.1  , 0.42  , 0.22  , 0.15  , -0.15 );
#         kernels[138] = compute_kernel(x,   9.72  , -6.47  , 6.89  , 0.28  , 2.07  , 1.58  , 0.85  , 0.37  , 0.16  , -0.42  , 0.11  , 0.12  , -0.24  , 0.13  , 0.13  , -0.42 );
#         kernels[139] = compute_kernel(x,   9.67  , -2.11  , 7.15  , 1.3  , 5.75  , 1.5  , 1.57  , 4.17  , 1.57  , 8.07  , 0.48  , 0.67  , 0.9  , -0.2  , 0.03  , 1.03 );
#         kernels[140] = compute_kernel(x,   9.68  , 3.3  , 8.42  , 2.67  , 1.93  , 1.48  , 0.97  , -0.23  , 0.73  , 0.29  , -0.08  , 0.51  , 0.15  , -0.14  , 0.1  , 0.39 );
#         kernels[141] = compute_kernel(x,   9.9  , 2.42  , 9.15  , 2.13  , 1.52  , 1.39  , 1.23  , -1.03  , -0.09  , 0.54  , -0.49  , -0.05  , 0.29  , 0.2  , 0.02  , -0.52 );
#         kernels[142] = compute_kernel(x,   9.51  , -7.95  , 4.83  , 0.16  , 1.66  , 1.39  , 0.65  , 1.3  , -0.21  , -0.46  , 0.56  , -0.23  , -0.43  , -0.04  , -0.09  , -0.3 );
#         kernels[143] = compute_kernel(x,   10.43  , 4.27  , 6.63  , 0.79  , 6.36  , 3.05  , 1.8  , -12.14  , -0.69  , 5.85  , -0.63  , -0.13  , 0.51  , -0.17  , -0.25  , 1.21 );
#         kernels[144] = compute_kernel(x,   9.93  , 6.1  , 6.9  , 1.04  , 3.08  , 2.03  , 2.1  , -0.86  , 1.32  , 3.69  , -0.14  , 0.31  , 0.57  , -0.09  , 0.08  , -1.08 );
#         kernels[145] = compute_kernel(x,   10.19  , -9.42  , 1.82  , 0.71  , 2.2  , 2.93  , 0.96  , 5.67  , -1.78  , -1.6  , 0.88  , -0.63  , -0.76  , 0.08  , -0.09  , 0.08 );
#         kernels[146] = compute_kernel(x,   9.47  , -3.2  , 8.59  , 1.25  , 2.1  , 1.56  , 0.73  , -1.16  , -0.19  , -0.11  , -0.36  , -0.17  , -0.07  , -0.05  , -0.18  , 0.18 );
#         kernels[147] = compute_kernel(x,   9.85  , -2.66  , 9.14  , 1.65  , 1.77  , 1.55  , 0.81  , -0.53  , -0.14  , -0.34  , -0.19  , -0.11  , -0.24  , -0.06  , -0.16  , -0.0 );
#         kernels[148] = compute_kernel(x,   9.68  , -1.53  , 8.48  , 1.26  , 3.65  , 2.19  , 1.07  , 6.08  , 1.82  , 2.59  , 0.76  , 0.78  , 0.67  , -0.12  , -0.12  , 1.35 );
#         kernels[149] = compute_kernel(x,   9.78  , 3.71  , 7.76  , 1.2  , 3.13  , 3.43  , 1.36  , -7.48  , 1.57  , -2.35  , -0.7  , 0.34  , -0.55  , 0.09  , 0.03  , 0.44 );
#         kernels[150] = compute_kernel(x,   9.8  , -7.7  , 3.15  , 4.34  , 2.04  , 2.38  , 1.27  , 2.58  , -1.74  , -1.58  , 0.53  , -0.57  , -0.61  , -0.11  , 0.01  , -0.4 );
#         kernels[151] = compute_kernel(x,   9.74  , 6.35  , 2.36  , 6.53  , 1.69  , 1.91  , 0.69  , -1.98  , -0.16  , 0.3  , -0.61  , -0.12  , 0.25  , 0.04  , 0.02  , -0.16 );
#         kernels[152] = compute_kernel(x,   10.27  , -8.52  , 0.35  , 4.07  , 2.43  , 3.87  , 1.3  , 7.68  , -3.83  , -3.03  , 0.82  , -0.76  , -0.96  , -0.26  , 0.05  , 0.14 );
#         kernels[153] = compute_kernel(x,   10.38  , -7.43  , 2.24  , 4.73  , 3.52  , 4.03  , 1.39  , 10.94  , -1.24  , -1.46  , 0.77  , -0.22  , -0.3  , -0.33  , -0.27  , 1.48 );
#         kernels[154] = compute_kernel(x,   10.1  , -0.08  , 4.28  , 5.82  , 6.55  , 2.65  , 1.8  , 0.91  , 0.9  , 3.53  , 0.05  , 0.19  , 0.3  , -0.05  , -0.32  , 2.28 );
#         kernels[155] = compute_kernel(x,   9.83  , 5.23  , 3.95  , 6.41  , 2.08  , 2.7  , 2.25  , -2.08  , 3.65  , -1.62  , -0.37  , 0.6  , -0.35  , 0.1  , 0.01  , 0.17 );
#         kernels[156] = compute_kernel(x,   10.09  , -2.25  , 4.8  , 4.55  , 6.36  , 3.82  , 1.83  , -17.19  , -4.61  , 7.1  , -0.71  , -0.66  , 0.61  , 0.02  , 0.05  , -1.37 );
#         kernels[157] = compute_kernel(x,   9.58  , -4.63  , 5.04  , 5.32  , 3.16  , 2.48  , 1.22  , 4.22  , 0.68  , 3.29  , 0.54  , 0.22  , 0.85  , -0.11  , 0.07  , 0.87 );
#         kernels[158] = compute_kernel(x,   9.82  , -7.01  , 4.35  , 4.89  , 2.87  , 1.15  , 1.19  , 0.09  , 0.04  , -2.85  , 0.03  , 0.03  , -0.83  , -0.15  , 0.03  , 0.13 );
#         kernels[159] = compute_kernel(x,   10.01  , -5.59  , 3.26  , 4.86  , 5.18  , 3.07  , 1.74  , -4.28  , -1.34  , 5.67  , -0.27  , -0.25  , 0.63  , 0.41  , 0.2  , -1.48 );
#         kernels[160] = compute_kernel(x,   9.89  , -3.98  , 4.16  , 4.75  , 5.97  , 3.13  , 2.05  , -2.77  , -3.44  , 4.36  , -0.15  , -0.54  , 0.36  , 0.26  , 0.19  , -1.44 );
#         kernels[161] = compute_kernel(x,   10.79  , 0.66  , 7.67  , 5.22  , 3.77  , 3.23  , 4.86  , -10.93  , 12.1  , -16.63  , -0.9  , 0.77  , -0.91  , -0.15  , -0.06  , 0.03 );
#         kernels[162] = compute_kernel(x,   10.21  , -4.89  , 3.21  , 4.63  , 6.8  , 3.29  , 1.71  , -9.73  , -1.87  , 8.73  , -0.44  , -0.33  , 0.75  , 0.2  , -0.11  , -0.84 );
#         kernels[163] = compute_kernel(x,   9.77  , -3.97  , 3.97  , 5.41  , 5.19  , 2.71  , 1.45  , 1.12  , 0.91  , 6.3  , 0.08  , 0.23  , 0.84  , -0.36  , -0.22  , 1.94 );
#         kernels[164] = compute_kernel(x,   10.07  , 6.88  , 4.26  , 5.78  , 0.86  , 1.15  , 0.99  , -0.45  , 0.06  , -0.11  , -0.45  , 0.05  , -0.12  , 0.02  , -0.14  , 0.32 );
#         kernels[165] = compute_kernel(x,   9.99  , 7.15  , 3.92  , 5.66  , 0.76  , 0.89  , 0.98  , 0.14  , -0.36  , 0.4  , 0.21  , -0.41  , 0.55  , -0.04  , -0.05  , -0.09 );
#         kernels[166] = compute_kernel(x,   10.17  , 5.4  , 2.43  , 7.07  , 1.15  , 3.97  , 1.46  , -2.83  , -4.39  , 0.76  , -0.62  , -0.76  , 0.45  , 0.61  , 0.17  , -0.71 );
#         kernels[167] = compute_kernel(x,   9.87  , 2.44  , 4.22  , 5.55  , 5.32  , 3.13  , 2.33  , -15.94  , -7.1  , 11.98  , -0.96  , -0.97  , 0.97  , -0.31  , -0.25  , 1.8 );
#         kernels[168] = compute_kernel(x,   10.26  , 6.8  , 2.29  , 7.11  , 0.55  , 1.51  , 1.08  , -0.41  , -1.1  , 0.48  , -0.49  , -0.67  , 0.81  , 0.49  , -0.18  , -0.14 );
#         kernels[169] = compute_kernel(x,   9.59  , 6.29  , 6.27  , 1.95  , 2.06  , 2.25  , 1.27  , -3.28  , -1.44  , 1.28  , -0.71  , -0.5  , 0.49  , -0.1  , 0.09  , 0.56 );
#         kernels[170] = compute_kernel(x,   9.93  , -4.87  , 7.84  , 0.19  , 4.52  , 1.37  , 1.05  , -4.46  , 0.95  , -2.5  , -0.72  , 0.66  , -0.52  , -0.0  , -0.12  , -0.13 );
#         kernels[171] = compute_kernel(x,   9.93  , -5.44  , 7.15  , -0.06  , 4.33  , 1.52  , 1.22  , -0.6  , 0.12  , 2.23  , -0.09  , 0.06  , 0.42  , -0.16  , 0.12  , 0.85 );
#         kernels[172] = compute_kernel(x,   9.96  , 2.02  , 6.23  , 0.47  , 7.2  , 2.03  , 1.5  , -7.98  , -0.27  , 7.82  , -0.55  , -0.09  , 0.73  , -0.03  , -0.06  , 1.35 );
#         kernels[173] = compute_kernel(x,   9.77  , 8.26  , 4.91  , 1.17  , 0.96  , 1.3  , 0.88  , 0.48  , 0.71  , 0.26  , 0.39  , 0.62  , 0.31  , 0.19  , -0.07  , -0.03 );
#         kernels[174] = compute_kernel(x,   9.93  , 4.51  , 7.37  , 1.06  , 4.0  , 2.99  , 0.69  , -9.09  , -0.16  , 0.5  , -0.76  , -0.08  , 0.18  , 0.07  , 0.12  , -1.3 );
#         kernels[175] = compute_kernel(x,   10.11  , -2.07  , 8.98  , 0.82  , 4.13  , 1.95  , 0.98  , 1.71  , 0.54  , 0.29  , 0.21  , 0.28  , 0.07  , -0.01  , -0.11  , -1.47 );
#         kernels[176] = compute_kernel(x,   9.96  , 5.76  , 3.59  , 6.5  , 1.05  , 3.09  , 2.09  , -1.14  , 4.32  , -0.05  , -0.35  , 0.67  , -0.02  , -0.01  , 0.04  , 0.81 );
#         kernels[177] = compute_kernel(x,   10.17  , 7.41  , 4.63  , 4.11  , 2.49  , 1.89  , 2.19  , -1.54  , 0.89  , -0.87  , -0.33  , 0.21  , -0.16  , 0.25  , -0.46  , 0.47 );
#         kernels[178] = compute_kernel(x,   9.59  , 7.75  , 4.0  , 3.41  , 2.15  , 1.3  , 1.83  , -0.22  , 0.24  , 2.39  , -0.08  , 0.1  , 0.61  , -0.3  , 0.45  , -0.17 );
#         kernels[179] = compute_kernel(x,   9.72  , 6.24  , 4.8  , 5.2  , 1.12  , 0.86  , 2.37  , 0.31  , 0.36  , -0.21  , 0.32  , 0.18  , -0.08  , -0.34  , 0.46  , -0.12 );
#         kernels[180] = compute_kernel(x,   11.34  , 4.22  , 6.35  , 5.87  , 3.24  , 5.26  , 4.77  , -6.75  , 19.77  , -0.02  , -0.4  , 0.79  , -0.0  , 0.26  , 0.0  , -0.61 );
#         kernels[181] = compute_kernel(x,   9.66  , -0.62  , 8.04  , 4.0  , 2.85  , 2.31  , 1.69  , 3.11  , -0.45  , -2.46  , 0.47  , -0.11  , -0.51  , 0.18  , -0.2  , 0.86 );
#         kernels[182] = compute_kernel(x,   10.54  , -7.62  , 4.45  , 4.25  , 4.79  , 3.0  , 2.26  , -5.58  , 3.22  , -7.73  , -0.39  , 0.47  , -0.71  , -0.22  , -0.04  , 0.05 );
#         kernels[183] = compute_kernel(x,   11.46  , -5.56  , 5.86  , 2.83  , 8.76  , 2.42  , 3.62  , -16.98  , 5.54  , -26.57  , -0.8  , 0.63  , -0.84  , -0.03  , -0.13  , -0.05 );
#         kernels[184] = compute_kernel(x,   11.36  , -6.75  , 6.36  , 2.62  , 7.61  , 2.41  , 3.19  , -14.88  , 4.3  , -18.94  , -0.81  , 0.56  , -0.78  , 0.03  , -0.05  , -0.05 );
#         kernels[185] = compute_kernel(x,   10.5  , -6.37  , 6.74  , 2.01  , 6.21  , 2.17  , 2.46  , -10.7  , 2.59  , -11.62  , -0.79  , 0.48  , -0.76  , -0.04  , 0.07  , -0.0 );
#         kernels[186] = compute_kernel(x,   9.65  , -1.74  , 6.88  , 2.69  , 5.07  , 5.08  , 1.77  , -13.81  , 5.1  , -2.05  , -0.54  , 0.57  , -0.23  , -0.25  , 0.11  , 0.93 );
#         kernels[187] = compute_kernel(x,   10.27  , 1.89  , 7.56  , 3.0  , 3.16  , 6.45  , 2.8  , -17.51  , 14.01  , -7.13  , -0.86  , 0.78  , -0.81  , -0.2  , -0.01  , 0.64 );
#         kernels[188] = compute_kernel(x,   11.51  , 1.27  , 9.06  , 3.84  , 3.65  , 5.45  , 3.5  , -17.25  , 16.12  , -11.92  , -0.87  , 0.85  , -0.93  , -0.13  , -0.16  , -0.16 );
#         kernels[189] = compute_kernel(x,   10.7  , 1.52  , 8.66  , 3.94  , 2.99  , 4.28  , 3.36  , -9.4  , 8.94  , -7.75  , -0.73  , 0.62  , -0.77  , 0.05  , -0.12  , 0.05 );
#         kernels[190] = compute_kernel(x,   10.07  , 3.8  , 7.79  , 3.86  , 1.17  , 3.85  , 3.24  , -0.15  , 7.48  , -1.01  , -0.03  , 0.6  , -0.27  , 0.14  , 0.11  , 0.35 );
#         kernels[191] = compute_kernel(x,   10.54  , 4.69  , 7.6  , 4.11  , 0.73  , 4.78  , 4.21  , 0.27  , 18.68  , -0.17  , 0.08  , 0.93  , -0.06  , -0.15  , 0.08  , 0.06 );
#         kernels[192] = compute_kernel(x,   10.05  , 4.39  , 7.1  , 4.09  , 0.71  , 5.42  , 4.56  , 2.0  , 22.96  , 1.83  , 0.52  , 0.93  , 0.57  , 0.01  , 0.02  , -0.0 );
#         kernels[193] = compute_kernel(x,   9.67  , 1.23  , 7.01  , 3.54  , 4.97  , 4.36  , 3.4  , -5.46  , 12.6  , 2.88  , -0.25  , 0.85  , 0.17  , 0.14  , -0.2  , -0.85 );
#         kernels[194] = compute_kernel(x,   9.38  , -1.39  , 8.98  , 1.97  , 1.13  , 1.13  , 0.59  , 0.16  , 0.06  , -0.1  , 0.12  , 0.09  , -0.15  , -0.16  , -0.03  , -0.48 );
#         kernels[195] = compute_kernel(x,   9.96  , 4.74  , 8.15  , 2.33  , 1.47  , 1.94  , 1.34  , -0.09  , -0.04  , -0.57  , -0.03  , -0.02  , -0.29  , -0.18  , -0.33  , 0.78 );
#         kernels[196] = compute_kernel(x,   9.89  , 4.72  , 6.34  , 4.27  , 2.77  , 2.85  , 1.77  , -3.13  , -3.75  , 0.44  , -0.4  , -0.74  , 0.09  , -0.1  , 0.34  , -0.4 );
#         kernels[197] = compute_kernel(x,   10.64  , 1.0  , 7.76  , 4.32  , 3.33  , 5.96  , 3.64  , -16.51  , 18.86  , -8.44  , -0.83  , 0.87  , -0.7  , -0.07  , 0.03  , 0.3 );
#         kernels[198] = compute_kernel(x,   11.06  , 3.26  , 7.55  , 4.74  , 2.02  , 6.01  , 4.14  , -8.25  , 18.81  , -3.32  , -0.68  , 0.76  , -0.4  , -0.02  , -0.08  , 0.29 );
#         kernels[199] = compute_kernel(x,   10.63  , 0.9  , 7.92  , 4.1  , 3.45  , 5.48  , 3.7  , -10.11  , 14.82  , -1.42  , -0.54  , 0.73  , -0.11  , 0.11  , -0.22  , -0.99 );
#         kernels[200] = compute_kernel(x,   10.1  , 1.67  , 3.92  , 5.11  , 5.87  , 4.94  , 1.64  , -26.32  , -7.12  , 7.56  , -0.91  , -0.88  , 0.79  , 0.36  , 0.54  , -0.7 );
#         kernels[201] = compute_kernel(x,   9.82  , 7.09  , 5.02  , 4.18  , 1.1  , 1.22  , 1.76  , 0.11  , 1.04  , 0.29  , 0.08  , 0.49  , 0.15  , -0.1  , -0.41  , 0.13 );
#         kernels[202] = compute_kernel(x,   10.19  , 7.36  , 4.91  , 4.64  , 1.59  , 0.96  , 1.44  , -0.29  , -0.01  , -0.7  , -0.19  , -0.01  , -0.31  , -0.17  , 0.49  , -0.23 );
#         kernels[203] = compute_kernel(x,   9.43  , -0.57  , 9.11  , 1.42  , 1.26  , 2.95  , 1.15  , -1.15  , -0.99  , -0.5  , -0.31  , -0.29  , -0.34  , 0.06  , -0.16  , -0.06 );
#         kernels[204] = compute_kernel(x,   10.02  , 2.31  , 7.7  , 2.52  , 3.94  , 3.89  , 1.94  , -10.95  , -6.49  , 6.33  , -0.71  , -0.86  , 0.83  , -0.43  , -0.08  , 1.29 );
#         kernels[205] = compute_kernel(x,   10.63  , -3.75  , 6.86  , 3.3  , 6.78  , 3.72  , 3.34  , -23.57  , 7.57  , -16.14  , -0.93  , 0.61  , -0.71  , -0.05  , 0.0  , -0.47 );
#         kernels[206] = compute_kernel(x,   11.81  , -5.3  , 7.69  , 2.97  , 7.11  , 3.51  , 2.59  , -22.88  , 2.66  , -9.15  , -0.92  , 0.29  , -0.5  , 0.03  , 0.04  , -0.04 );
#         kernels[207] = compute_kernel(x,   9.87  , 3.84  , 6.34  , 5.04  , 1.35  , 4.06  , 4.39  , -4.64  , 15.74  , -4.5  , -0.85  , 0.88  , -0.76  , -0.24  , -0.03  , 0.2 );
#         kernels[208] = compute_kernel(x,   10.61  , 6.13  , 3.66  , 6.31  , 1.47  , 4.16  , 3.9  , 0.41  , 10.0  , 1.74  , 0.07  , 0.62  , 0.3  , -0.06  , 0.21  , 0.56 );
#         kernels[209] = compute_kernel(x,   10.22  , 5.57  , 3.56  , 6.2  , 1.44  , 3.37  , 5.67  , -0.49  , 15.25  , 0.03  , -0.1  , 0.8  , 0.0  , -0.07  , -0.1  , -0.54 );
#         kernels[210] = compute_kernel(x,   10.0  , 2.27  , 3.85  , 5.82  , 4.8  , 4.93  , 1.52  , -21.68  , -3.15  , 4.72  , -0.92  , -0.42  , 0.65  , 0.8  , 0.73  , -1.27 );
#         kernels[211] = compute_kernel(x,   10.95  , -5.07  , 7.19  , 2.2  , 7.06  , 2.08  , 1.77  , -10.49  , 0.32  , 0.62  , -0.71  , 0.09  , 0.05  , -0.12  , 0.09  , -0.04 );
#         kernels[212] = compute_kernel(x,   10.34  , 4.25  , 4.45  , 6.39  , 2.94  , 4.15  , 1.79  , -8.65  , -6.55  , 4.31  , -0.71  , -0.88  , 0.82  , -0.35  , -0.57  , 1.07 );
#         kernels[213] = compute_kernel(x,   10.02  , 3.23  , 4.7  , 5.53  , 4.06  , 4.15  , 2.25  , -12.21  , -8.12  , 7.38  , -0.73  , -0.87  , 0.81  , 0.88  , 0.02  , -1.2 );
#         kernels[214] = compute_kernel(x,   11.9  , 6.06  , 4.2  , 6.35  , 1.54  , 4.7  , 7.2  , 2.29  , 31.56  , 2.23  , 0.32  , 0.93  , 0.2  , 0.09  , 0.04  , 0.06 );
#         kernels[215] = compute_kernel(x,   12.2  , 5.86  , 4.91  , 6.81  , 1.19  , 5.21  , 7.05  , 0.2  , 34.15  , 0.02  , 0.03  , 0.93  , 0.0  , 0.09  , 0.06  , -0.11 );
#         kernels[216] = compute_kernel(x,   10.88  , 4.26  , 7.1  , 3.11  , 1.72  , 6.26  , 5.33  , -7.95  , 30.59  , -5.25  , -0.74  , 0.92  , -0.57  , -0.05  , 0.14  , -0.09 );
#         kernels[217] = compute_kernel(x,   12.09  , 3.58  , 7.73  , 4.93  , 1.93  , 7.15  , 6.22  , -11.89  , 42.9  , -10.2  , -0.86  , 0.97  , -0.85  , -0.06  , 0.07  , 0.0 );
#         kernels[218] = compute_kernel(x,   12.5  , 3.28  , 7.38  , 4.92  , 2.48  , 7.65  , 6.91  , -17.39  , 51.31  , -15.09  , -0.92  , 0.97  , -0.88  , -0.07  , 0.1  , -0.17 );
#         kernels[219] = compute_kernel(x,   11.42  , 1.85  , 7.16  , 4.05  , 3.39  , 6.32  , 5.91  , -16.37  , 33.33  , -12.97  , -0.76  , 0.89  , -0.65  , 0.0  , -0.06  , -1.0 );
#         kernels[220] = compute_kernel(x,   10.26  , 4.51  , 8.03  , 4.43  , 0.71  , 0.94  , 0.63  , 0.65  , -0.38  , -0.23  , 0.98  , -0.64  , -0.52  , 0.23  , -0.07  , 0.03 );
#         kernels[221] = compute_kernel(x,   9.57  , 4.93  , 6.24  , -0.04  , 0.86  , 2.92  , 4.71  , 0.02  , 12.01  , -1.09  , 0.01  , 0.87  , -0.27  , 1.18  , -0.21  , 0.57 );
#         kernels[222] = compute_kernel(x,   9.82  , 5.6  , 2.15  , -6.11  , 2.12  , 3.44  , 3.26  , -5.23  , 2.07  , 2.33  , -0.72  , 0.19  , 0.34  , 0.91  , -0.37  , 0.47 );
#         kernels[223] = compute_kernel(x,   11.41  , 6.46  , 2.42  , -7.34  , 3.66  , 1.42  , 4.05  , 1.08  , 0.06  , 13.43  , 0.21  , 0.01  , 0.91  , -0.11  , -0.07  , -0.23 );
#         kernels[224] = compute_kernel(x,   11.34  , 3.43  , 6.43  , -6.5  , 4.38  , 3.82  , 1.54  , -16.11  , -4.7  , 5.84  , -0.96  , -0.8  , 0.86  , -0.18  , 0.12  , 0.01 );
#         kernels[225] = compute_kernel(x,   11.22  , 6.48  , 5.26  , -4.59  , 3.32  , 4.93  , 1.4  , -15.5  , -6.33  , 3.88  , -0.95  , -0.92  , 0.83  , -0.03  , -0.01  , 0.14 );
#         kernels[226] = compute_kernel(x,   11.23  , 5.72  , 6.04  , -5.12  , 3.02  , 4.76  , 0.92  , -13.59  , -3.77  , 2.09  , -0.95  , -0.86  , 0.75  , -0.03  , 0.06  , 0.1 );
#         kernels[227] = compute_kernel(x,   11.02  , 5.44  , 6.05  , -5.36  , 2.82  , 4.34  , 1.05  , -11.56  , -3.55  , 2.1  , -0.95  , -0.78  , 0.71  , -0.06  , -0.08  , 0.04 );
#         kernels[228] = compute_kernel(x,   10.6  , 6.43  , 5.18  , -5.18  , 2.22  , 3.45  , 1.15  , -6.36  , -0.08  , 1.06  , -0.83  , -0.02  , 0.41  , -0.13  , 0.01  , 0.04 );
#         kernels[229] = compute_kernel(x,   10.64  , 6.98  , 4.92  , -4.94  , 1.79  , 3.51  , 1.05  , -4.84  , 0.24  , 0.82  , -0.77  , 0.06  , 0.43  , -0.02  , 0.01  , 0.1 );
#         kernels[230] = compute_kernel(x,   10.44  , 7.31  , 4.55  , -5.0  , 1.31  , 2.77  , 0.95  , -2.23  , 0.36  , 0.75  , -0.61  , 0.13  , 0.6  , 0.0  , -0.03  , 0.1 );
#         kernels[231] = compute_kernel(x,   10.45  , 7.44  , 4.68  , -5.1  , 1.23  , 2.06  , 0.86  , -1.21  , 0.23  , 0.76  , -0.48  , 0.13  , 0.73  , -0.01  , 0.0  , -0.0 );
#         kernels[232] = compute_kernel(x,   10.46  , 7.77  , 4.46  , -4.89  , 1.1  , 1.91  , 0.83  , -1.21  , -0.48  , 0.79  , -0.58  , -0.3  , 0.86  , -0.03  , 0.05  , 0.13 );
#         kernels[233] = compute_kernel(x,   10.4  , 8.14  , 3.74  , -4.58  , 1.23  , 2.23  , 0.94  , -2.21  , -1.24  , 0.68  , -0.81  , -0.59  , 0.59  , -0.05  , 0.11  , 0.14 );
#         kernels[234] = compute_kernel(x,   10.62  , 8.68  , 3.65  , -3.72  , 1.72  , 2.67  , 1.29  , -2.87  , -2.0  , 0.61  , -0.62  , -0.58  , 0.27  , -0.02  , 0.17  , -0.08 );
#         kernels[235] = compute_kernel(x,   10.71  , 8.5  , 3.68  , -3.8  , 2.12  , 3.04  , 1.71  , -4.19  , -1.27  , 0.08  , -0.65  , -0.24  , 0.02  , 0.08  , -0.17  , -0.16 );
#         kernels[236] = compute_kernel(x,   10.33  , 0.51  , 6.43  , -7.93  , 0.95  , 2.16  , 2.29  , -1.8  , -4.32  , 1.74  , -0.88  , -0.87  , 0.8  , -0.01  , -0.01  , -0.03 );
#         kernels[237] = compute_kernel(x,   10.25  , 0.73  , 6.1  , -8.06  , 1.01  , 1.9  , 2.22  , -1.6  , -3.46  , 1.44  , -0.84  , -0.82  , 0.64  , 0.23  , 0.41  , -0.27 );
#         kernels[238] = compute_kernel(x,   11.74  , 6.53  , 4.91  , -4.84  , 3.62  , 5.73  , 1.93  , -19.07  , -10.4  , 5.89  , -0.92  , -0.94  , 0.84  , -0.08  , 0.06  , 0.08 );
#         kernels[239] = compute_kernel(x,   11.11  , 6.29  , 5.25  , -5.11  , 2.75  , 4.55  , 2.09  , -10.74  , -8.43  , 4.53  , -0.86  , -0.89  , 0.79  , 0.07  , -0.04  , -0.07 );
#         kernels[240] = compute_kernel(x,   12.12  , 6.74  , 3.15  , -6.41  , 3.89  , 2.12  , 5.98  , -2.02  , -4.5  , 22.66  , -0.24  , -0.35  , 0.97  , 0.02  , -0.02  , -0.05 );
#         kernels[241] = compute_kernel(x,   12.08  , 3.59  , 6.6  , -6.73  , 4.85  , 2.2  , 4.78  , -8.51  , -7.79  , 21.25  , -0.8  , -0.74  , 0.92  , -0.07  , -0.17  , -0.57 );
#         kernels[242] = compute_kernel(x,   10.38  , 7.39  , 3.75  , -5.82  , 1.13  , 1.89  , 0.74  , -1.63  , -0.24  , 0.49  , -0.77  , -0.17  , 0.59  , -0.19  , 0.14  , 0.09 );
#         kernels[243] = compute_kernel(x,   10.45  , 7.94  , 2.36  , -5.87  , 1.0  , 2.27  , 0.61  , -1.67  , -0.52  , 0.12  , -0.74  , -0.38  , 0.2  , -0.02  , -0.04  , -0.08 );
#         kernels[244] = compute_kernel(x,   10.36  , 7.81  , 2.55  , -5.97  , 0.86  , 1.89  , 0.61  , -1.03  , -0.23  , -0.09  , -0.63  , -0.2  , -0.17  , -0.04  , -0.04  , -0.04 );
#         kernels[245] = compute_kernel(x,   10.45  , 7.72  , 2.67  , -6.01  , 0.97  , 2.25  , 0.75  , -1.86  , 0.04  , 0.07  , -0.85  , 0.02  , 0.09  , -0.06  , -0.03  , -0.06 );
#         kernels[246] = compute_kernel(x,   10.39  , 2.25  , 8.79  , -4.39  , 1.85  , 1.48  , 1.79  , -0.77  , -0.59  , 2.58  , -0.28  , -0.22  , 0.78  , 0.05  , 0.2  , -0.26 );
#         kernels[247] = compute_kernel(x,   10.49  , 2.2  , 8.45  , -4.31  , 3.0  , 2.47  , 2.53  , -5.03  , -3.74  , 6.2  , -0.68  , -0.6  , 0.82  , -0.01  , 0.04  , -0.03 );
#         kernels[248] = compute_kernel(x,   11.83  , 7.84  , 3.79  , -3.79  , 3.5  , 2.85  , 5.81  , -4.74  , -9.57  , 19.04  , -0.47  , -0.58  , 0.94  , 0.01  , 0.2  , 0.3 );
#         kernels[249] = compute_kernel(x,   11.49  , 6.63  , 3.62  , -6.18  , 2.99  , 3.1  , 4.72  , -5.24  , -7.6  , 12.72  , -0.56  , -0.52  , 0.9  , 0.1  , -0.36  , -0.5 );
#         kernels[250] = compute_kernel(x,   10.0  , 6.42  , 4.31  , -5.64  , 2.51  , 1.23  , 1.33  , -1.45  , -0.44  , 2.2  , -0.47  , -0.27  , 0.66  , -0.2  , -0.02  , 0.43 );
#         kernels[251] = compute_kernel(x,   10.41  , 6.91  , 4.84  , -5.49  , 1.96  , 1.71  , 0.97  , -2.35  , -0.36  , 1.2  , -0.7  , -0.21  , 0.63  , -0.02  , -0.02  , 0.01 );
#         kernels[252] = compute_kernel(x,   10.27  , 7.13  , 4.46  , -5.39  , 1.47  , 1.83  , 0.73  , -1.84  , -0.08  , 0.63  , -0.69  , -0.06  , 0.59  , 0.03  , -0.01  , 0.05 );
#         kernels[253] = compute_kernel(x,   10.25  , 6.96  , 4.19  , -5.78  , 1.55  , 1.63  , 1.22  , -1.75  , -1.27  , 1.01  , -0.69  , -0.64  , 0.53  , 0.05  , -0.18  , -0.2 );
#         kernels[254] = compute_kernel(x,   11.27  , 4.52  , 2.7  , -8.42  , 3.82  , 1.93  , 3.48  , 1.97  , 2.0  , 12.76  , 0.27  , 0.3  , 0.96  , -0.32  , 0.34  , -0.33 );
#         kernels[255] = compute_kernel(x,   11.14  , 5.05  , 4.89  , -6.2  , 3.57  , 2.75  , 4.41  , -0.18  , 2.51  , 13.88  , -0.02  , 0.21  , 0.88  , -0.39  , 0.45  , -0.53 );
#         kernels[256] = compute_kernel(x,   10.26  , 6.65  , 5.04  , -5.57  , 1.86  , 0.93  , 0.97  , -1.34  , -0.42  , 0.95  , -0.77  , -0.47  , 0.53  , -0.05  , -0.0  , 0.1 );
#         kernels[257] = compute_kernel(x,   10.34  , 7.06  , 4.73  , -5.31  , 1.89  , 1.8  , 0.72  , -2.87  , -0.68  , 0.67  , -0.85  , -0.53  , 0.49  , -0.15  , -0.05  , 0.11 );
#         kernels[258] = compute_kernel(x,   10.51  , 7.26  , 4.55  , -5.35  , 1.89  , 2.3  , 0.55  , -3.65  , -0.46  , 0.54  , -0.84  , -0.36  , 0.52  , -0.19  , -0.09  , 0.08 );
#         kernels[259] = compute_kernel(x,   10.44  , 7.09  , 4.63  , -5.3  , 1.79  , 2.61  , 0.36  , -3.88  , -0.08  , 0.13  , -0.83  , -0.08  , 0.2  , -0.05  , -0.04  , 0.03 );
#         kernels[260] = compute_kernel(x,   10.45  , 7.04  , 4.6  , -5.32  , 1.93  , 2.7  , 0.32  , -4.62  , -0.18  , 0.2  , -0.89  , -0.21  , 0.32  , -0.02  , -0.05  , 0.0 );
#         kernels[261] = compute_kernel(x,   9.96  , 6.59  , 4.31  , -5.31  , 2.08  , 2.48  , 0.5  , -3.38  , -0.52  , 0.13  , -0.66  , -0.42  , 0.13  , -0.11  , -0.11  , -0.13 );
#         kernels[262] = compute_kernel(x,   10.35  , 6.43  , 4.78  , -6.21  , 1.02  , 1.75  , 0.71  , -1.61  , -0.52  , 0.3  , -0.9  , -0.42  , 0.41  , -0.18  , -0.06  , -0.11 );
#         kernels[263] = compute_kernel(x,   10.32  , 5.89  , 5.36  , -6.1  , 1.47  , 1.73  , 1.12  , -2.09  , -1.15  , 1.31  , -0.82  , -0.59  , 0.79  , -0.01  , -0.03  , -0.11 );
#         kernels[264] = compute_kernel(x,   10.26  , 0.11  , 6.83  , -7.18  , 2.35  , 2.23  , 1.2  , -4.45  , -2.4  , 2.51  , -0.85  , -0.9  , 0.89  , -0.05  , -0.05  , 0.13 );
#         kernels[265] = compute_kernel(x,   10.34  , 0.67  , 6.94  , -7.13  , 2.22  , 2.48  , 1.08  , -4.83  , -2.51  , 2.08  , -0.88  , -0.94  , 0.87  , -0.05  , -0.08  , 0.18 );
#         kernels[266] = compute_kernel(x,   10.22  , 1.19  , 6.66  , -7.09  , 2.26  , 2.68  , 1.11  , -5.97  , -2.85  , 2.42  , -0.98  , -0.96  , 0.96  , -0.05  , -0.07  , 0.1 );
#         kernels[267] = compute_kernel(x,   9.93  , 1.61  , 6.23  , -7.01  , 2.17  , 2.58  , 1.12  , -5.35  , -2.74  , 2.31  , -0.95  , -0.95  , 0.95  , 0.02  , -0.0  , 0.05 );
#         kernels[268] = compute_kernel(x,   10.06  , 1.79  , 6.15  , -7.24  , 2.03  , 2.49  , 1.02  , -4.71  , -2.38  , 1.93  , -0.93  , -0.94  , 0.94  , 0.07  , 0.02  , 0.14 );
#         kernels[269] = compute_kernel(x,   10.35  , 1.83  , 6.3  , -7.4  , 2.11  , 2.71  , 0.89  , -5.28  , -2.19  , 1.77  , -0.92  , -0.9  , 0.94  , -0.01  , 0.02  , 0.08 );
# ...
#                     + kernels[55] * 0.344007147
#                     + kernels[57] * 0.109780108
#                     + kernels[58]
#                     + kernels[62]
#                     + kernels[63]
#                     + kernels[64]
#                     + kernels[65]
#                     + kernels[66]
#                     + kernels[67]
#                     + kernels[68]
#                     + kernels[69]
#                     + kernels[70]
#                     + kernels[71]
#                     + kernels[72]
#                     + kernels[74]
#                     + kernels[75]
#                     + kernels[76]
#                     + kernels[77]
#                     + kernels[78]
#                     + kernels[79]
#                     + kernels[80]
#                     + kernels[81]
#                     + kernels[82]
#                     + kernels[83]
#                     + kernels[86] * 0.0040574
#                     + kernels[93] * 0.081827793
#                     + kernels[97] * 0.217811416
#                     + kernels[102] * 0.154903297
#                     + kernels[105] * 0.07809302
#                     + kernels[107] * 0.563332624
#                     + kernels[111] * 0.220036094
#                     + kernels[121]
#                     - kernels[335]
#                     - kernels[336]
#                     + kernels[340] * -0.280784768
#                     - kernels[352]
#                     + kernels[355] * -0.629998779
#                     + kernels[361] * -0.180321654
#                     + kernels[363] * -0.839413648
#                     - kernels[365]
#                     - kernels[366]
#                     - kernels[367]
#                     - kernels[368]
#                     - kernels[369]
#                     - kernels[370]
#                     - kernels[371]
#                     - kernels[372]
#                     - kernels[373]
#                     - kernels[374]
#                     - kernels[375]
#                     - kernels[377]
#                     - kernels[378]
#                     - kernels[379]
#                     - kernels[380]
#                     - kernels[381]
#                     + kernels[382] * -0.790326815
#                     - kernels[383]
#                     - kernels[384]
#                     - kernels[385]
#                     - kernels[386]
#                     - kernels[387]
#                     - kernels[388]
#                     - kernels[389]
#                     - kernels[391]
#                     - kernels[392]
#                     - kernels[393]
#                     - kernels[395]
#                     - kernels[396]
#                     - kernels[397]
#                     - kernels[398]
#                     - kernels[399]
#                     - kernels[401]
#                     - kernels[402]
#                     - kernels[403]
#                     - kernels[405]
#                     - kernels[406]
#                     - kernels[407]
#                     - kernels[408]
#                     - kernels[410]
#                     - kernels[412]
#                     - kernels[414]
#                     - kernels[416]
#                     - kernels[419]
#         ;
#         decisions[3] = 0.146177752
#                     + kernels[125] * 0.131768836
#                     + kernels[126] * 0.338593485
#                     + kernels[127] * 0.677079576
#                     + kernels[128] * 0.114854915
#                     + kernels[129] * 0.474582565
#                     + kernels[130] * 0.080371754
#                     + kernels[131] * 0.304333479
#                     + kernels[133] * 0.500021704
#                     + kernels[135] * 0.153162552
#                     + kernels[137]
#                     + kernels[139] * 0.361876658
#                     + kernels[140]
#                     + kernels[141]
#                     + kernels[142] * 0.022420577
#                     + kernels[143] * 0.640403306
#                     + kernels[144]
#                     + kernels[145] * 0.09738133
#                     + kernels[147] * 0.765295214
#                     + kernels[148] * 0.530800975
#                     + kernels[152] * 0.208526113
#                     + kernels[153] * 0.130801439
#                     + kernels[161] * 0.534041236
#                     + kernels[162] * 0.052747015
#                     + kernels[165] * 0.229754078
#                     + kernels[167] * 0.14536621
#                     + kernels[169] * 0.86113241
#                     + kernels[172] * 0.207405629
#                     + kernels[173]
#                     + kernels[178] * 0.95171835
#                     + kernels[182] * 0.047682228
#                     + kernels[183] * 0.705297079
#                     + kernels[185] * 0.301420989
#                     + kernels[186] * 0.020125632
#                     + kernels[187] * 0.320470507
#                     + kernels[188] * 0.010721343
#                     + kernels[189] * 0.037133187
#                     + kernels[190] * 0.637280224
#                     + kernels[191] * 0.576236849
#                     + kernels[192] * 0.115788445
#                     + kernels[193] * 0.185822491
#                     + kernels[194]
#                     + kernels[195]
#                     + kernels[197] * 0.297224687
#                     + kernels[199] * 0.021410453
#                     + kernels[200] * 0.746400523
#                     + kernels[201]
#                     + kernels[202]
#                     + kernels[203]
#                     + kernels[204] * 0.836903337
#                     + kernels[205] * 0.318502165
#                     + kernels[206] * 0.539917474
#                     + kernels[207] * 0.743140982
#                     + kernels[209] * 0.244254036
#                     + kernels[210] * 0.190335969
#                     + kernels[211] * 0.065999319
#                     + kernels[214] * 0.365732575
#                     + kernels[215] * 0.346969608
#                     + kernels[216] * 0.407465018
#                     + kernels[217] * 0.420978551
#                     + kernels[218] * 0.71416734
#                     + kernels[219] * 0.580819683
#                     - kernels[220]
#                     - kernels[221]
#                     + kernels[224] * -0.024836677
#                     + kernels[226] * -0.871195951
#                     + kernels[235] * -0.569861589
#                     + kernels[238] * -0.85576225
#                     + kernels[240] * -0.527580193
#                     + kernels[241] * -0.416681971
#                     + kernels[247] * -0.038214331
#                     + kernels[248] * -0.370963986
#                     + kernels[254] * -0.337039568
#                     + kernels[255] * -0.19920192
#                     - kernels[275]
#                     - kernels[276]
#                     - kernels[277]
#                     - kernels[278]
#                     - kernels[279]
#                     - kernels[289]
#                     - kernels[290]
#                     - kernels[291]
#                     - kernels[292]
#                     - kernels[293]
#                     - kernels[294]
#                     - kernels[295]
#                     - kernels[296]
#                     - kernels[300]
#                     + kernels[301] * -0.140364076
#                     + kernels[302] * -0.610890626
#                     + kernels[303] * -0.545006092
#                     + kernels[304] * -0.430302736
#                     + kernels[305] * -0.379161433
#                     + kernels[306] * -0.135875739
#                     + kernels[310] * -0.178089255
#                     + kernels[315] * -0.197018153
#                     + kernels[319] * -0.476932383
#                     - kernels[322]
#                     + kernels[324] * -0.118814795
#                     + kernels[325] * -0.389767533
#                     + kernels[326] * -0.144761668
#                     + kernels[327] * -0.315741179
#                     + kernels[328] * -0.837935398
#                     + kernels[329] * -0.386390092
#                     + kernels[330] * -0.373106072
#                     + kernels[331] * -0.668054784
#                     + kernels[332] * -0.02729558
#                     + kernels[333] * -0.445173336
#                     + kernels[334] * -0.300620731
#         ;
#         decisions[4] = 0.740200499
#                     + kernels[124] * 0.034485587
#                     + kernels[126] * 0.100462854
#                     + kernels[127] * 0.212320531
#                     + kernels[128] * 0.033721272
#                     + kernels[129] * 0.172283839
#                     + kernels[135] * 0.101785694
#                     + kernels[137]
#                     + kernels[138] * 0.190599213
#                     + kernels[143] * 0.256898542
#                     + kernels[144]
#                     + kernels[146] * 0.909679219
#                     + kernels[149]
#                     + kernels[156] * 0.030519345
#                     + kernels[161] * 0.148026333
#                     + kernels[167] * 0.051369878
#                     + kernels[169]
#                     + kernels[170] * 0.480768649
#                     + kernels[171] * 0.303729182
#                     + kernels[173]
#                     + kernels[174]
#                     + kernels[175] * 0.430812632
#                     + kernels[178] * 0.799969152
#                     + kernels[180] * 0.045903221
#                     + kernels[183] * 0.204199635
#                     + kernels[184] * 0.035043009
#                     + kernels[187] * 0.103267574
#                     + kernels[188] * 0.004725364
#                     + kernels[191] * 0.038153035
#                     + kernels[192] * 0.087328576
#                     + kernels[194] * 0.317936472
#                     + kernels[195] * 0.257349256
#                     + kernels[197] * 0.081586875
#                     + kernels[198] * 0.046635921
#                     + kernels[200] * 0.219407894
#                     + kernels[203]
#                     + kernels[204] * 0.159260597
#                     + kernels[205] * 0.090246646
#                     + kernels[206] * 0.181399041
#                     + kernels[207] * 0.008495947
#                     + kernels[209] * 0.043488625
#                     + kernels[214] * 0.077417546
#                     + kernels[215] * 0.127778407
#                     + kernels[216] * 0.106981176
#                     + kernels[217] * 0.129170265
#                     + kernels[218] * 0.216460334
#                     + kernels[219] * 0.179148178
#                     + kernels[338] * -0.201680269
#                     - kernels[344]
#                     - kernels[345]
#                     - kernels[350]
#                     + kernels[352] * -0.859572229
#                     + kernels[353] * -0.890963031
#                     + kernels[363] * -0.791387557
#                     - kernels[365]
#                     - kernels[368]
#                     - kernels[369]
#                     - kernels[376]
#                     - kernels[378]
#                     - kernels[393]
#                     + kernels[395] * -0.275212428
#                     - kernels[407]
#                     - kernels[417]
#         ;
#         decisions[5] = 1.043495365
#                     + kernels[220] * 0.343697195
#                     + kernels[221] * 0.213015879
#                     + kernels[226] * 0.736347734
#                     + kernels[227] * 0.939743069
#                     + kernels[228]
#                     + kernels[229]
#                     + kernels[230]
#                     + kernels[231]
#                     + kernels[232]
#                     + kernels[233]
#                     + kernels[234]
#                     + kernels[235]
#                     + kernels[236] * 0.051274005
#                     + kernels[237]
#                     + kernels[246]
#                     + kernels[250]
#                     + kernels[251]
#                     + kernels[252]
#                     + kernels[256]
#                     + kernels[257]
#                     + kernels[258]
#                     + kernels[259]
#                     + kernels[260]
#                     + kernels[261]
#                     + kernels[262]
#                     + kernels[263]
#                     + kernels[264]
#                     + kernels[265]
#                     + kernels[266]
#                     + kernels[267]
#                     + kernels[268]
#                     + kernels[269] * 0.798824674
#                     + kernels[270]
#                     + kernels[272]
#                     + kernels[273]
#                     + kernels[274]
#                     + kernels[275]
#                     + kernels[276]
#                     + kernels[277]
#                     + kernels[278]
#                     + kernels[281]
#                     + kernels[282]
#                     + kernels[283]
#                     + kernels[284]
#                     + kernels[285]
#                     + kernels[286]
#                     + kernels[287]
#                     + kernels[288]
#                     + kernels[289]
#                     + kernels[290]
#                     + kernels[291]
#                     + kernels[292]
#                     + kernels[293]
#                     + kernels[294]
#                     + kernels[296] * 0.16673879
#                     + kernels[300]
#                     + kernels[320] * 0.796800995
#                     + kernels[321]
#                     + kernels[322]
#                     + kernels[323]
#                     - kernels[335]
#                     + kernels[336] * -0.46421102
#                     - kernels[337]
#                     + kernels[338] * -0.15676108
#                     - kernels[339]
#                     - kernels[341]
#                     - kernels[342]
#                     - kernels[343]
#                     + kernels[346] * -0.413485197
#                     - kernels[347]
#                     - kernels[348]
#                     - kernels[349]
#                     - kernels[350]
#                     + kernels[351] * -0.952044167
#                     - kernels[352]
#                     - kernels[354]
#                     - kernels[356]
#                     - kernels[357]
#                     - kernels[358]
#                     - kernels[359]
#                     - kernels[360]
#                     - kernels[362]
#                     + kernels[363] * -0.881779274
#                     - kernels[364]
#                     - kernels[365]
#                     + kernels[366] * -0.657943651
#                     - kernels[368]
#                     - kernels[369]
#                     - kernels[370]
#                     - kernels[371]
#                     - kernels[373]
#                     - kernels[374]
#                     - kernels[375]
#                     - kernels[377]
#                     - kernels[378]
#                     - kernels[380]
#                     - kernels[382]
#                     - kernels[383]
#                     - kernels[386]
#                     - kernels[388]
#                     - kernels[389]
#                     - kernels[390]
#                     - kernels[391]
#                     - kernels[394]
#                     - kernels[395]
#                     + kernels[396] * -0.858047822
#                     + kernels[397] * -0.171856235
#                     + kernels[398] * -0.255950604
#                     - kernels[400]
#                     - kernels[402]
#                     - kernels[403]
#                     - kernels[404]
#                     - kernels[405]
#                     - kernels[407]
#                     - kernels[409]
#                     - kernels[411]
#                     - kernels[413]
#                     - kernels[415]
#                     + kernels[417] * -0.234363291
#                     - kernels[418]
#                     - kernels[419]
#         ;
#         votes[decisions[0] > 0 ? 0 : 1] += 1;
#         votes[decisions[1] > 0 ? 0 : 2] += 1;
#         votes[decisions[2] > 0 ? 0 : 3] += 1;
#         votes[decisions[3] > 0 ? 1 : 2] += 1;
#         votes[decisions[4] > 0 ? 1 : 3] += 1;
#         votes[decisions[5] > 0 ? 2 : 3] += 1;
#                 int classVal = -1;
#         int classIdx = -1;
#         for (int i = 0; i < 4; i++) {
#             if (votes[i] > classVal) {
#                 classVal = votes[i];
#                 classIdx = i;
#             }
#         }
#         return classIdx;
# }
